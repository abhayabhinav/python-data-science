# %%
def add_num(x, y , z=None):
    if z != None:
        sum = x + y + z
    else:
        sum = x + y
    return sum

# %%
print(add_num(1,2))
# Out:
# 3

# %%
print(add_num(1,2, 3))
# Out:
# 6

# %%
config = ('database', 'username', 'pwd')

# %%
for items in config:
    print(items)
# Out:
# database
# username
# pwd

# %%
if 'database' in config:
    print('tuple type')
else:
    print('list type')
# Out:
# tuple type

# %%
abhinav_degree = {'Bachelor\'s': 'Computer Science', 'Master\'s': 'Data Science'}

# %%
for keys in abhinav_degree:
    print(abhinav_degree[keys])
# Out:
# Computer Science
# Data Science

# %%
for keys in abhinav_degree.values():
    print(keys)
# Out:
# Computer Science
# Data Science

# %%
import csv

# %%
with open('dataset\mpg.csv') as csvfile:
    mpg = list(csv.DictReader(csvfile))
    
mpg[:3]
# Out:
# [OrderedDict([('', '1'),
#               ('manufacturer', 'audi'),
#               ('model', 'a4'),
#               ('displ', '1.8'),
#               ('year', '1999'),
#               ('cyl', '4'),
#               ('trans', 'auto(l5)'),
#               ('drv', 'f'),
#               ('cty', '18'),
#               ('hwy', '29'),
#               ('fl', 'p'),
#               ('class', 'compact')]),
#  OrderedDict([('', '2'),
#               ('manufacturer', 'audi'),
#               ('model', 'a4'),
#               ('displ', '1.8'),
#               ('year', '1999'),
#               ('cyl', '4'),
#               ('trans', 'manual(m5)'),
#               ('drv', 'f'),
#               ('cty', '21'),
#               ('hwy', '29'),
#               ('fl', 'p'),
#               ('class', 'compact')]),
#  OrderedDict([('', '3'),
#               ('manufacturer', 'audi'),
#               ('model', 'a4'),
#               ('displ', '2'),
#               ('year', '2008'),
#               ('cyl', '4'),
# ...

# %%
mpg[0].keys()
# Out:
# odict_keys(['', 'manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty', 'hwy', 'fl', 'class'])

# %%
value = 0
for items in mpg:
    value = value + float(items['cty'])
avg_city_mpg = value/len(mpg)
print(avg_city_mpg)
# Out:
# 16.858974358974358

# %%
avg_city_mpg = sum(float(d['cty']) for d in mpg) / len(mpg)  # ✅
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5020\3788285921.py in <module>
# ----> 1 avg_city_mpg = sum(float(d['cty']) for d in mpg) / len(mpg)  # ✅
#
# TypeError: 'float' object is not callable

# %%
print(avg_city_mpg)

# %% [markdown]
# # problem - Get avg mpg by cylinder in cty
# 1. Get unique cylinder
# 2. Get lenght of each type of unique cylinder
# 3. Get Sum of cty where cylinder is x
# 4. Find avg for each of them

# %%
cylinders = set(d['cyl'] for d in mpg)
cylinders

# %%
cylinders = set()
for items in mpg:
    cylinders.add(items['cyl'])
cylinders

# %%
cty_cylinder_mpg = []
for c in cylinders:
    sum = 0
    cylinder_count = 0
    for d in mpg:
        if d['cyl'] == c:
            sum+= float(d['cty'])
            cylinder_count+= 1
    cty_cylinder_mpg.append((c, sum/cylinder_count))
cty_cylinder_mpg.sort(key = lambda x:x[0])
cty_cylinder_mpg

# %% [markdown]
# # Avg city mpg across all cars

# %%
mpg[0].keys()

# %%
sum=0
count=0
for d in mpg:
    sum+= float(d['cty'])
    count+= 1

avg_cty_mpg_all_cars = sum/count
print(f'Avg mileage across all cars is {avg_cty_mpg_all_cars:.2f} ')

# %% [markdown]
# # Get the car size list , avg mpg in city by size of the car

# %%
car_class = set(d['class'] for d in mpg)
car_class
# Out:
# {'2seater', 'compact', 'midsize', 'minivan', 'pickup', 'subcompact', 'suv'}

# %%
type(car_class)
# Out:
# set

# %%
car_class_mpg = []
for c in car_class:
    sum = 0
    car_class_count = 0
    avg_mpg_by_car_class = 0
    for items in mpg:
        if items['class'] == c:
            sum+= float(items['cty'])
            car_class_count+=1
    avg_mpg_by_car_class = sum/car_class_count
    car_class_mpg.append((c, avg_mpg_by_car_class))
car_class_mpg.sort(key=lambda x:x[0])
car_class_mpg
# Out:
# [('2seater', 15.4),
#  ('compact', 20.127659574468087),
#  ('midsize', 18.75609756097561),
#  ('minivan', 15.818181818181818),
#  ('pickup', 13.0),
#  ('subcompact', 20.37142857142857),
#  ('suv', 13.5)]

# %%
car_mpg_by_class = []
for c in car_class:
    sum = 0
    count = 0
    avg_by_class = 0
    for d in mpg:
        if d['class'] == c:
            sum+= float(d['cty'])
            count+= 1
    avg_by_class = sum/count
    car_mpg_by_class.append((c, avg_by_class))
# lambda argument : what_to_return
car_mpg_by_class.sort(key=lambda x : x[1])
car_mpg_by_class
# Out:
# [('pickup', 13.0),
#  ('suv', 13.5),
#  ('2seater', 15.4),
#  ('minivan', 15.818181818181818),
#  ('midsize', 18.75609756097561),
#  ('compact', 20.127659574468087),
#  ('subcompact', 20.37142857142857)]

# %%
import datetime as dt
import time as tm

# %%
dtnow = dt.datetime.fromtimestamp(tm.time())
dtnow
# Out:
# datetime.datetime(2026, 5, 14, 5, 40, 34, 751060)

# %%
today = dt.datetime.today()
today
# Out:
# datetime.datetime(2026, 5, 14, 5, 40, 34, 784611)

# %%
delta = dt.timedelta(days = 100)
today - delta
# Out:
# datetime.datetime(2026, 2, 3, 5, 40, 34, 784611)

# %%
today > (today - delta)
# Out:
# True
