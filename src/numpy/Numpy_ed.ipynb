# %%
import numpy as np

# %%
import math

# %%
a = np.array([1,2,3])
a.ndim
# Out:
# 1

# %%
b = np.array([[1,2,3], [4,5,6]])
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (2, 3)

# %%
b.dtype
# Out:
# dtype('int32')

# %%
c = np.array([2.2, 5, 1.1])
c.dtype.name
# Out:
# 'float64'

# %%
d = np.zeros((2,3))
d
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
e = np.ones((2,3))
e
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.random.rand(2,3)
# Out:
# array([[0.12095586, 0.42823712, 0.83013704],
#        [0.73310537, 0.35507748, 0.5441795 ]])
